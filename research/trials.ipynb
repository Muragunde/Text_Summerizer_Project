# %%
d = {"key":"value", "key1":"value1"}

# %%
d["key"]
# Out:
# 'value'

# %%
d.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 d.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
from box import ConfigBox

# %%
d1 = ConfigBox({"key":"value", "key1":"value1"})

# %%
d1["key"]
# Out:
# 'value'

# %%
d1.key
# Out:
# 'value'

# %%
def mul(x:int, y:int) -> int:
    return x*y

# %%
mul(2,3)
# Out:
# 6

# %%
mul(2,"4")
# Out:
# '44'

# %%
from ensure import ensure annotations
# Out:
#   Cell In[17], line 1
#     from ensure import ensure annotations
#                               ^
# SyntaxError: invalid syntax

# %%
from ensure import ensure_annotations
@ensure_annotations
def mul(x:int, y:int) -> int:
    return x*y

# %%
mul(2,3)
# Out:
# 6

# %%
mul(2,"4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 mul(2,"4")
#
# File c:\Users\HP\.conda\envs\textS\lib\site-packages\ensure\main.py:845, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     840     if not isinstance(value, templ):
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
# --> 845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
#     849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function mul at 0x0000021D39ADE8C0> does not match annotation type <class 'int'>
